# %% [markdown]
# # CIFAR-10 dataset classification with CNNs
#
# Author: Tanwi Mallick, adapting codes from Bethany Lusch, Prasanna Balprakash, Corey Adams, and Kyle Felker
#
# In this notebook, we'll continue the CIFAR-10 problem using the Keras API (as included in the TensorFlow library) and incorporating convolutional layers.
#
# First, the needed imports.

# %%
# %matplotlib inline

import tensorflow as tf

import numpy
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ## CIFAR-10 data set
#
# Again we'll load the cifar10 data set. CIFAR-10 dataset contains 32x32 color images from 10 classes: airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck. If you haven't downloaded it already, it could take a while.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train = x_train.astype(numpy.float32)
x_test  = x_test.astype(numpy.float32)

x_train /= 255.
x_test  /= 255.

y_train = y_train.astype(numpy.int32)
y_test  = y_test.astype(numpy.int32)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step

# %% [markdown]
# This time we won't flatten the images.
#
# The training data (`X_train`) is a 3rd-order tensor of size (50000, 32, 32), i.e. it consists of 50000 images of size 32x32 pixels.
#
# `y_train` is a 50000-dimensional vector containing the correct classes ('airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck') for each training sample.

# %% [markdown]
# ## Convolutional neural network (CNN)
#
# CNN is a type of deep learning model for processing data that has a grid pattern, such as images.
#
# Let's use a small model that includes convolutional layers
#
# - The Conv2D layers operate on 2D matrices so we input the images directly to the model.
#     - The two Conv2D layers below learn 32 and 64 filters respectively.
#     - They are learning filters for 3x3 windows.
# - The MaxPooling2D layer reduces the spatial dimensions, that is, makes the image smaller.
#     - It downsamples by taking the maximum value in the window
#     - The pool size of (2, 2) below means the windows are 2x2.
#     - Helps in extracting important features and reduce computation
# - The Flatten layer flattens the 2D matrices into vectors, so we can then switch to Dense layers as in the MLP model.
#
# See https://keras.io/layers/convolutional/, https://keras.io/layers/pooling/ for more information.

# %% [markdown]
# ![conv layer](https://github.com/YTTARA/ai-science-training-series/blob/main/03_neural_networks_tensorflow/images/conv_layer.png?raw=1)
# Image credit: [Jason Brownlee](https://machinelearningmastery.com/convolutional-layers-for-deep-learning-neural-networks/)

# %% [markdown]
# ![conv layer](https://github.com/YTTARA/ai-science-training-series/blob/main/03_neural_networks_tensorflow/images/conv.png?raw=1)
# Image credit: [Anh H. Reynolds](https://anhreynolds.com/blogs/cnn.html)

# %% [markdown]
# <img src="https://github.com/YTTARA/ai-science-training-series/blob/main/03_neural_networks_tensorflow/images/MaxpoolSample2.png?raw=1" width="600" hight="600" align="left"/>

# %%
class CIFAR10Classifier(tf.keras.models.Model):

    def __init__(self, activation=tf.nn.tanh):
        tf.keras.models.Model.__init__(self)

        self.conv_1 = tf.keras.layers.Conv2D(32, [3, 3], activation='relu')
        self.conv_2 = tf.keras.layers.Conv2D(64, [3, 3], activation='relu')
        self.pool_3 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))
        self.drop_4 = tf.keras.layers.Dropout(0.25)
        self.dense_5 = tf.keras.layers.Dense(128, activation='relu')
        self.drop_6 = tf.keras.layers.Dropout(0.5)
        self.dense_7 = tf.keras.layers.Dense(10, activation='softmax')

    def call(self, inputs):

        x = self.conv_1(inputs)
        x = self.conv_2(x)
        x = self.pool_3(x)
        x = self.drop_4(x)
        x = tf.keras.layers.Flatten()(x)
        x = self.dense_5(x)
        x = self.drop_6(x)
        x = self.dense_7(x)

        return x

# %% [markdown]
# ### Simple training

# %% [markdown]
# Here is a concise way to train the network, like we did in the previous notebook. We'll see a more verbose approach below that allows more performance tuning.

# %%
def train_network_concise(_batch_size, _n_training_epochs, _lr):

    cnn_model = CIFAR10Classifier()

    cnn_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=['accuracy'])
    
    history = cnn_model.fit(x_train, y_train, batch_size=_batch_size, epochs=_n_training_epochs)
    return history, cnn_model

# %%
# This took 43 seconds per epoch on my laptop
batch_size = 512
epochs = 3
lr = .01
history, cnn_model = train_network_concise(batch_size, epochs, lr)
# Out:
# Epoch 1/3
# 98/98 [==============================] - 13s 37ms/step - loss: 1.8331 - accuracy: 0.3284
# Epoch 2/3
# 98/98 [==============================] - 3s 34ms/step - loss: 1.4683 - accuracy: 0.4720
# Epoch 3/3
# 98/98 [==============================] - 4s 40ms/step - loss: 1.3403 - accuracy: 0.5227

# %% [markdown]
# Accuracy for test data.  The model should be better than the non-convolutional model even if you're only patient enough for three epochs.

# %%
plt.figure(figsize=(5,3))
plt.plot(history.epoch,history.history['loss'])
plt.title('loss')

plt.figure(figsize=(5,3))
plt.plot(history.epoch,history.history['accuracy'])
plt.title('accuracy');

# %% [markdown]
# ### Inference

# %% [markdown]
# With enough training epochs, the test accuracy should exceed 96.53%.
#
# You can compare your result with the state-of-the art [here](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html).

# %%
# %%time
x_test_reshaped = numpy.expand_dims(x_test, -1)
scores = cnn_model.evaluate(x_test, y_test, verbose=2)
print("%s: %.2f%%" % (cnn_model.metrics_names[1], scores[1]*100))
# Out:
# 313/313 - 2s - loss: 1.1888 - accuracy: 0.5830 - 2s/epoch - 6ms/step
# accuracy: 58.30%
# CPU times: user 1.66 s, sys: 169 ms, total: 1.83 s
# Wall time: 2.14 s

# %% [markdown]
# We can also again check the confusion matrix

# %%
from sklearn.metrics import confusion_matrix

print('Confusion matrix (rows: true classes; columns: predicted classes):'); print()
predictions = cnn_model.predict(x_test)
cm=confusion_matrix(y_test, numpy.argmax(predictions, axis=1), labels=list(range(10)))
print(cm); print()

print('Classification accuracy for each class:'); print()
for i,j in enumerate(cm.diagonal()/cm.sum(axis=1)): print("%d: %.4f" % (i,j))
# Out:
# Confusion matrix (rows: true classes; columns: predicted classes):
#
# 313/313 [==============================] - 2s 5ms/step
# [[766  64  20  10  18   4  16  20  28  54]
#  [ 24 839   1   7   2   3  10  10   7  97]
#  [130  32 270  68 189  88 109  77  12  25]
#  [ 32  41  53 348  76 159 142 106   5  38]
#  [ 57  15  53  60 480  25 127 162   7  14]
#  [ 21  12  50 169  63 473  62 132   8  10]
#  [ 10  28  23  39  69  15 755  26   4  31]
#  [ 24  10  14  32  40  56  19 767   2  36]
#  [264 137   5  12   6  13  10   9 486  58]
#  [ 59 214   3   6   6   6  18  32  10 646]]
#
# Classification accuracy for each class:
#
# 0: 0.7660
# 1: 0.8390
# 2: 0.2700
# 3: 0.3480
# 4: 0.4800
# 5: 0.4730
# 6: 0.7550
# 7: 0.7670
# 8: 0.4860
# 9: 0.6460

# %% [markdown]
# ### More verbose training

# %% [markdown]
# This approach explicitly handles the looping over data. It will be helpful in future weeks for diving in and optimizing

# %%
def compute_loss(y_true, y_pred):
    # if labels are integers, use sparse categorical crossentropy
    # network's final layer is softmax, so from_logtis=False
    scce = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
    # if labels are one-hot encoded, use standard crossentropy

    return scce(y_true, y_pred)

# %%
def forward_pass(model, batch_data, y_true):
    y_pred = model(batch_data)
    loss = compute_loss(y_true, y_pred)
    return loss

# %%
# Here is a function that will manage the training loop for us:

def train_loop(batch_size, n_training_epochs, model, opt):
    
    @tf.function()
    def train_iteration(data, y_true, model, opt):
        with tf.GradientTape() as tape:
            loss = forward_pass(model, data, y_true)

        trainable_vars = model.trainable_variables

        # Apply the update to the network (one at a time):
        grads = tape.gradient(loss, trainable_vars)

        opt.apply_gradients(zip(grads, trainable_vars))
        return loss

    for i_epoch in range(n_training_epochs):
        print("beginning epoch %d" % i_epoch)
        start = time.time()

        epoch_steps = int(50000/batch_size)
        dataset.shuffle(50000) # Shuffle the whole dataset in memory
        batches = dataset.batch(batch_size=batch_size, drop_remainder=True)
        
        for i_batch, (batch_data, y_true) in enumerate(batches):
            batch_data = tf.reshape(batch_data, [-1, 32, 32, 3])
            loss = train_iteration(batch_data, y_true, model, opt)
            
        end = time.time()
        print("took %1.1f seconds for epoch #%d" % (end-start, i_epoch))

# %%
def train_network(_batch_size, _n_training_epochs, _lr):

    cifar_model = CIFAR10Classifier()

    opt = tf.keras.optimizers.Adam(_lr)

    train_loop(_batch_size, _n_training_epochs, cifar_model, opt)

# %%
dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
dataset.shuffle(50000)

batch_size = 512
epochs = 3
lr = .01
train_network(batch_size, epochs, lr)
# Out:
# beginning epoch 0
# took 4.8 seconds for epoch #0
# beginning epoch 1
# took 3.3 seconds for epoch #1
# beginning epoch 2
# took 2.8 seconds for epoch #2

# %% [markdown]
# # Homework: improve the accuracy of this model

# %% [markdown]
# Update this notebook to ensure more accuracy. How high can it be raised? Changes like increasing the number of epochs, altering the learning rate, altering the number of neurons the hidden layer, chnaging the optimizer, etc. could be made directly in the notebook. You can also change the model specification by expanding the network's layer. The current notebook's training accuracy is roughly 58.06%, although it varies randomly.

# %%
class CIFAR10Classifier(tf.keras.models.Model):

    def __init__(self, activation=tf.nn.tanh):
        tf.keras.models.Model.__init__(self)

        self.conv_1 = tf.keras.layers.Conv2D(32, [3, 3], activation='relu')
        self.conv_2 = tf.keras.layers.Conv2D(64, [3, 3], activation='relu')
        self.conv_3 = tf.keras.layers.Conv2D(128, [3, 3], activation='relu')
        self.drop_4 = tf.keras.layers.Dropout(0.25)
        self.conv_5 = tf.keras.layers.Conv2D(256, [3, 3], activation='relu')
        self.pool_6 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))
        self.drop_7 = tf.keras.layers.Dropout(0.25)
        self.conv_8 = tf.keras.layers.Conv2D(64, [3, 3], activation='relu')
        self.pool_9 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))
        self.dense_10 = tf.keras.layers.Dense(128, activation='relu')
        self.drop_11 = tf.keras.layers.Dropout(0.5)
        self.dense_12 = tf.keras.layers.Dense(10, activation='softmax')

    def call(self, inputs):

        x = self.conv_1(inputs)
        x = self.conv_2(x)
        x = self.conv_3(x)
        x = self.drop_4(x)
        x = self.conv_5(x)
        x = self.pool_6(x)
        x = self.drop_7(x)
        x = self.conv_8(x)
        x = self.pool_9(x)
        x = tf.keras.layers.Flatten()(x)
        x = self.dense_10(x)
        x = self.drop_11(x)
        x = self.dense_12(x)

        return x


def train_network_concise(_batch_size, _n_training_epochs, _lr):

    cnn_model = CIFAR10Classifier()

    cnn_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=['accuracy'])
    
    history = cnn_model.fit(x_train, y_train, batch_size=_batch_size, epochs=_n_training_epochs)
    return history, cnn_model


# changing learning rate and increasing epoch
# This took 43 seconds per epoch on my laptop
batch_size = 512
epochs = 100
lr = .01
history, cnn_model = train_network_concise(batch_size, epochs, lr)


plt.figure(figsize=(5,3))
plt.plot(history.epoch,history.history['loss'])
plt.title('loss')

plt.figure(figsize=(5,3))
plt.plot(history.epoch,history.history['accuracy'])
plt.title('accuracy');
# Out:
# Epoch 1/100
# 98/98 [==============================] - 20s 176ms/step - loss: 1.9650 - accuracy: 0.2721
# Epoch 2/100
# 98/98 [==============================] - 16s 162ms/step - loss: 1.5564 - accuracy: 0.4347
# Epoch 3/100
# 98/98 [==============================] - 16s 162ms/step - loss: 1.4016 - accuracy: 0.4968
# Epoch 4/100
# 98/98 [==============================] - 16s 162ms/step - loss: 1.3017 - accuracy: 0.5393
# Epoch 5/100
# 98/98 [==============================] - 16s 161ms/step - loss: 1.1945 - accuracy: 0.5779
# Epoch 6/100
# 98/98 [==============================] - 16s 161ms/step - loss: 1.1066 - accuracy: 0.6078
# Epoch 7/100
# 98/98 [==============================] - 16s 161ms/step - loss: 1.0253 - accuracy: 0.6399
# Epoch 8/100
# 98/98 [==============================] - 16s 164ms/step - loss: 0.9642 - accuracy: 0.6631
# Epoch 9/100
# 98/98 [==============================] - 16s 161ms/step - loss: 0.9148 - accuracy: 0.6808
# Epoch 10/100
# 98/98 [==============================] - 16s 161ms/step - loss: 0.8753 - accuracy: 0.6904
# Epoch 11/100
# 98/98 [==============================] - 16s 161ms/step - loss: 0.8360 - accuracy: 0.7075
# Epoch 12/100
# 98/98 [==============================] - 16s 161ms/step - loss: 0.8062 - accuracy: 0.7178
# Epoch 13/100
# 98/98 [==============================] - 16s 161ms/step - loss: 0.7738 - accuracy: 0.7282
# Epoch 14/100
# 98/98 [==============================] - 16s 161ms/step - loss: 0.7427 - accuracy: 0.7399
# Epoch 15/100
# 98/98 [==============================] - 16s 161ms/step - loss: 0.7171 - accuracy: 0.7482
# Epoch 16/100
# 98/98 [==============================] - 16s 162ms/step - loss: 0.6950 - accuracy: 0.7561
# Epoch 17/100
# 98/98 [==============================] - 16s 161ms/step - loss: 0.6826 - accuracy: 0.7612
# Epoch 18/100
# 98/98 [==============================] - 16s 161ms/step - loss: 0.6597 - accuracy: 0.7686
# Epoch 19/100
# 98/98 [==============================] - 16s 161ms/step - loss: 0.6411 - accuracy: 0.7746
# Epoch 20/100
# 98/98 [==============================] - 16s 161ms/step - loss: 0.6150 - accuracy: 0.7820
# Epoch 21/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.6091 - accuracy: 0.7870
# Epoch 22/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.5913 - accuracy: 0.7908
# Epoch 23/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.5714 - accuracy: 0.7977
# Epoch 24/100
# 98/98 [==============================] - 16s 161ms/step - loss: 0.5616 - accuracy: 0.7992
# Epoch 25/100
# 98/98 [==============================] - 16s 161ms/step - loss: 0.5492 - accuracy: 0.8059
# Epoch 26/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.5341 - accuracy: 0.8106
# Epoch 27/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.5227 - accuracy: 0.8124
# Epoch 28/100
# 98/98 [==============================] - 16s 161ms/step - loss: 0.5054 - accuracy: 0.8206
# Epoch 29/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.5010 - accuracy: 0.8196
# Epoch 30/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.4840 - accuracy: 0.8269
# Epoch 31/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.4706 - accuracy: 0.8304
# Epoch 32/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.4667 - accuracy: 0.8327
# Epoch 33/100
# 98/98 [==============================] - 16s 161ms/step - loss: 0.4564 - accuracy: 0.8348
# Epoch 34/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.4531 - accuracy: 0.8366
# Epoch 35/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.4246 - accuracy: 0.8472
# Epoch 36/100
# 98/98 [==============================] - 16s 161ms/step - loss: 0.4297 - accuracy: 0.8443
# Epoch 37/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.4141 - accuracy: 0.8502
# Epoch 38/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.4034 - accuracy: 0.8546
# Epoch 39/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.3971 - accuracy: 0.8563
# Epoch 40/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.3947 - accuracy: 0.8577
# Epoch 41/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.3841 - accuracy: 0.8611
# Epoch 42/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.3802 - accuracy: 0.8619
# Epoch 43/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.3737 - accuracy: 0.8635
# Epoch 44/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.3707 - accuracy: 0.8659
# Epoch 45/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.3549 - accuracy: 0.8693
# Epoch 46/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.3460 - accuracy: 0.8742
# Epoch 47/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.3407 - accuracy: 0.8765
# Epoch 48/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.3495 - accuracy: 0.8739
# Epoch 49/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.3403 - accuracy: 0.8755
# Epoch 50/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.3287 - accuracy: 0.8786
# Epoch 51/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.3308 - accuracy: 0.8789
# Epoch 52/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.3215 - accuracy: 0.8808
# Epoch 53/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.3174 - accuracy: 0.8829
# Epoch 54/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.3077 - accuracy: 0.8863
# Epoch 55/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.3081 - accuracy: 0.8871
# Epoch 56/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.3005 - accuracy: 0.8893
# Epoch 57/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2896 - accuracy: 0.8940
# Epoch 58/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2868 - accuracy: 0.8954
# Epoch 59/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2865 - accuracy: 0.8949
# Epoch 60/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2876 - accuracy: 0.8939
# Epoch 61/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2777 - accuracy: 0.8986
# Epoch 62/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2850 - accuracy: 0.8952
# Epoch 63/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2802 - accuracy: 0.8952
# Epoch 64/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2775 - accuracy: 0.8993
# Epoch 65/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2693 - accuracy: 0.9000
# Epoch 66/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2648 - accuracy: 0.9015
# Epoch 67/100
# 98/98 [==============================] - 16s 159ms/step - loss: 0.2758 - accuracy: 0.9000
# Epoch 68/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2532 - accuracy: 0.9052
# Epoch 69/100
# 98/98 [==============================] - 16s 159ms/step - loss: 0.2687 - accuracy: 0.9024
# Epoch 70/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2576 - accuracy: 0.9052
# Epoch 71/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2487 - accuracy: 0.9081
# Epoch 72/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2503 - accuracy: 0.9085
# Epoch 73/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2432 - accuracy: 0.9102
# Epoch 74/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2330 - accuracy: 0.9143
# Epoch 75/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2294 - accuracy: 0.9148
# Epoch 76/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2438 - accuracy: 0.9113
# Epoch 77/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2377 - accuracy: 0.9141
# Epoch 78/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2320 - accuracy: 0.9150
# Epoch 79/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2281 - accuracy: 0.9165
# Epoch 80/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2354 - accuracy: 0.9149
# Epoch 81/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2336 - accuracy: 0.9148
# Epoch 82/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2152 - accuracy: 0.9212
# Epoch 83/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2275 - accuracy: 0.9164
# Epoch 84/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2154 - accuracy: 0.9212
# Epoch 85/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2178 - accuracy: 0.9201
# Epoch 86/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2121 - accuracy: 0.9234
# Epoch 87/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2113 - accuracy: 0.9226
# Epoch 88/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2071 - accuracy: 0.9232
# Epoch 89/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2139 - accuracy: 0.9215
# Epoch 90/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2115 - accuracy: 0.9231
# Epoch 91/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2138 - accuracy: 0.9205
# Epoch 92/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2022 - accuracy: 0.9257
# Epoch 93/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2096 - accuracy: 0.9254
# Epoch 94/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2020 - accuracy: 0.9272
# Epoch 95/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2045 - accuracy: 0.9261
# Epoch 96/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2018 - accuracy: 0.9271
# Epoch 97/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2085 - accuracy: 0.9242
# Epoch 98/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.1971 - accuracy: 0.9287
# Epoch 99/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.2040 - accuracy: 0.9259
# Epoch 100/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.1955 - accuracy: 0.9293

# %% [markdown]
# Accuracy increased from 58.06% to 92.93%
