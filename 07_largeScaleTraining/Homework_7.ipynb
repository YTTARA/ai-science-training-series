# %% [markdown]
# I tried running this code but got the following errors.
# I posted the error in Slack and got direction from Kyle.
# I was trying to run it in thetalogin4 while I should have tried this on a compute node.
# I initialted an interactive job to run the process but got stuck in queue.
# Finally I couldn’t complete the run.

# %% [markdown]
# # these are the steps for the run that I was following
#
# # initiating interactive job
# qsub-gpu -n 1 -t 15 -q full-node -A ALCFAITP -I --attrs filesystems=home,grand
#
# # run the dependencies
# module load conda
# conda activate base
# cd Argonne_AI_training/07_largeScaleTraining
# mkdir -p venvs/thetaGPU/2022-07-01
# python3 -m venv venvs/thetaGPU/2022-07-01 --system-site-packages
# source venvs/thetaGPU/2022-07-01/bin/activate
# python3 -m pip install -e .
# python3 -m pip install --upgrade pip
# python3 -m pip install hydra-core hydra_colorlog
# cd src/ai4sci
#
# # run the file
# chmod +x main.sh
# qsub-gpu main.sh

# %% [markdown]
# ![Error_log.png](attachment:Error_log.png)

# %% [markdown]
# ![_1.png](attachment:_1.png)

# %% [markdown]
# ![-2.png](attachment:-2.png)
